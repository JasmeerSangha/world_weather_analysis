# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime
import time
from scipy.stats import linregress

# %%
# Import timeit.
#import timeit
#%timeit np.random.uniform(-90.000, 90.000, size=1500)

# %%
lat=np.random.uniform(-90,90,1500)
lng=np.random.uniform(-90,90,1500)
lat_lng=zip(lat,lng)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lng)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 583

# %%
city_data = []
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key


# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | east london
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | saldanha
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | geraldton
# Processing Record 8 of Set 1 | rocha
# Processing Record 9 of Set 1 | gander
# Processing Record 10 of Set 1 | taoudenni
# Processing Record 11 of Set 1 | harper
# Processing Record 12 of Set 1 | hiriyur
# Processing Record 13 of Set 1 | sundumbili
# Processing Record 14 of Set 1 | ponta do sol
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | olafsvik
# Processing Record 17 of Set 1 | vestmanna
# Processing Record 18 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 1 | fort abbas
# Processing Record 20 of Set 1 | bereda
# Processing Record 21 of Set 1 | san luis
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | longyearbyen
# Processing Record 24 of Set 1 | areal
# Processing Record 25 of Set 1 | mecca
# Processing Record 26 of Set 1 | dikson
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | porto santo
# Processing Record 29 of Set 1 | clyde river
# Processing Record 30 of Set 1 | quatre cocos
# Processing Record 31 of Set 1 | carnot
# Processing Record 32 of Set 1 | rondonopolis
# Processing Record 33 of Set 1 | desaguadero
# Processing Record 34 of Set 1 | sinnamary
# Processing Record 35 of Set 1 | salalah
# Processing Record 36 of Set 1 | atbasar
# Processing Record 37 of Set 1 | coquimbo
# Processing Record 38 of Set 1 | mahon
# Processing Record 39 of Set 1 | kasongo
# Processing Record 40 of Set 1 | arlit
# Processing Record 41 of Set 1 | strangnas
# Processing Record 42 of Set 1 | marsa matruh
# Processing Record 43 of Set 1 | puerto carreno
# Processing Record 44 of Set 1 | talnakh
# Processing Record 45 of Set 1 | phuntsholing
# Processing Record 46 of Set 1 | torbay
# Processing Record 47 of Set 1 | cabedelo
# Processing Record 48 of Set 1 | marfino
# Processing Record 49 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 50 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 2 | codrington
# Processing Record 2 of Set 2 | jurm
# Processing Record 3 of Set 2 | huarmey
# Processing Record 4 of Set 2 | xuddur
# Processing Record 5 of Set 2 | semirom
# Processing Record 6 of Set 2 | ribeira grande
# Processing Record 7 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 2 | kovdor
# Processing Record 9 of Set 2 | ciudad bolivar
# Processing Record 10 of Set 2 | mar del plata
# Processing Record 11 of Set 2 | vila velha
# Processing Record 12 of Set 2 | iaciara
# Processing Record 13 of Set 2 | thompson
# Processing Record 14 of Set 2 | chuy
# Processing Record 15 of Set 2 | fereydunshahr
# Processing Record 16 of Set 2 | kruisfontein
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 2 | belmonte
# Processing Record 19 of Set 2 | hamilton
# Processing Record 20 of Set 2 | nuuk
# Processing Record 21 of Set 2 | skelleftea
# Processing Record 22 of Set 2 | vestmannaeyjar
# Processing Record 23 of Set 2 | felidhoo
# City not found. Skipping...
# Processing Record 24 of Set 2 | santa cruz de la palma
# Processing Record 25 of Set 2 | barwaha
# City not found. Skipping...
# Processing Record 26 of Set 2 | victoria
# Processing Record 27 of Set 2 | bud
# Processing Record 28 of Set 2 | asosa
# Processing Record 29 of Set 2 | saint anthony
# Processing Record 30 of Set 2 | berlevag
# Processing Record 31 of Set 2 | canoa
# Processing Record 32 of Set 2 | hithadhoo
# Processing Record 33 of Set 2 | farafangana
# Processing Record 34 of Set 2 | lodwar
# Processing Record 35 of Set 2 | sorland
# Processing Record 36 of Set 2 | adrar
# Processing Record 37 of Set 2 | beisfjord
# Processing Record 38 of Set 2 | busselton
# Processing Record 39 of Set 2 | tasiilaq
# Processing Record 40 of Set 2 | mwinilunga
# Processing Record 41 of Set 2 | la macarena
# Processing Record 42 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | fasa
# Processing Record 45 of Set 2 | krechevitsy
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | necochea
# Processing Record 48 of Set 2 | bambous virieux
# Processing Record 49 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 2 | bilma
# Processing Record 1 of Set 3 | amsterdam
# Processing Record 2 of Set 3 | saint-francois
# Processing Record 3 of Set 3 | touros
# Processing Record 4 of Set 3 | luderitz
# Processing Record 5 of Set 3 | qaanaaq
# Processing Record 6 of Set 3 | kirishi
# Processing Record 7 of Set 3 | sete
# Processing Record 8 of Set 3 | axim
# Processing Record 9 of Set 3 | reconquista
# Processing Record 10 of Set 3 | karaton
# Processing Record 11 of Set 3 | riyadh
# Processing Record 12 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 13 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 3 | comodoro rivadavia
# Processing Record 15 of Set 3 | sao joao da barra
# Processing Record 16 of Set 3 | namibe
# Processing Record 17 of Set 3 | port alfred
# Processing Record 18 of Set 3 | takoradi
# Processing Record 19 of Set 3 | peniche
# Processing Record 20 of Set 3 | acarau
# Processing Record 21 of Set 3 | antofagasta
# Processing Record 22 of Set 3 | shache
# Processing Record 23 of Set 3 | sinjar
# Processing Record 24 of Set 3 | grand gaube
# Processing Record 25 of Set 3 | souillac
# Processing Record 26 of Set 3 | trincomalee
# Processing Record 27 of Set 3 | arraial do cabo
# Processing Record 28 of Set 3 | horodnytsya
# Processing Record 29 of Set 3 | mitsamiouli
# Processing Record 30 of Set 3 | carnarvon
# Processing Record 31 of Set 3 | lebu
# Processing Record 32 of Set 3 | port elizabeth
# Processing Record 33 of Set 3 | karatau
# Processing Record 34 of Set 3 | asfi
# Processing Record 35 of Set 3 | chintamani
# Processing Record 36 of Set 3 | saint george
# Processing Record 37 of Set 3 | uthal
# Processing Record 38 of Set 3 | bombay
# Processing Record 39 of Set 3 | kindu
# Processing Record 40 of Set 3 | batticaloa
# Processing Record 41 of Set 3 | hobyo
# Processing Record 42 of Set 3 | bentiu
# Processing Record 43 of Set 3 | gurupi
# Processing Record 44 of Set 3 | umm kaddadah
# Processing Record 45 of Set 3 | ongandjera
# Processing Record 46 of Set 3 | padron
# Processing Record 47 of Set 3 | wum
# Processing Record 48 of Set 3 | westpunt
# City not found. Skipping...
# Processing Record 49 of Set 3 | tabriz
# Processing Record 50 of Set 3 | isaka
# Processing Record 1 of Set 4 | san andres
# Processing Record 2 of Set 4 | langen
# Processing Record 3 of Set 4 | ponta delgada
# Processing Record 4 of Set 4 | atar
# Processing Record 5 of Set 4 | katerero
# Processing Record 6 of Set 4 | cidreira
# Processing Record 7 of Set 4 | chaves
# Processing Record 8 of Set 4 | gamba
# Processing Record 9 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 4 | balkhash
# Processing Record 11 of Set 4 | vila franca do campo
# Processing Record 12 of Set 4 | kavaratti
# Processing Record 13 of Set 4 | jesup
# Processing Record 14 of Set 4 | deolali
# Processing Record 15 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 4 | cherepanovo
# Processing Record 17 of Set 4 | saint-georges
# Processing Record 18 of Set 4 | san lorenzo
# Processing Record 19 of Set 4 | upernavik
# Processing Record 20 of Set 4 | narsaq
# Processing Record 21 of Set 4 | mount pleasant
# Processing Record 22 of Set 4 | muros
# Processing Record 23 of Set 4 | carutapera
# Processing Record 24 of Set 4 | talcahuano
# Processing Record 25 of Set 4 | amapa
# Processing Record 26 of Set 4 | nouadhibou
# Processing Record 27 of Set 4 | ostrovnoy
# Processing Record 28 of Set 4 | tombouctou
# Processing Record 29 of Set 4 | bogorodskoye
# Processing Record 30 of Set 4 | sao filipe
# Processing Record 31 of Set 4 | venice
# Processing Record 32 of Set 4 | dhanaura
# Processing Record 33 of Set 4 | konin
# Processing Record 34 of Set 4 | tabas
# Processing Record 35 of Set 4 | khash
# Processing Record 36 of Set 4 | lugovoy
# Processing Record 37 of Set 4 | roald
# Processing Record 38 of Set 4 | houma
# Processing Record 39 of Set 4 | hit
# Processing Record 40 of Set 4 | puerto narino
# Processing Record 41 of Set 4 | camacha
# Processing Record 42 of Set 4 | wattegama
# Processing Record 43 of Set 4 | hofn
# Processing Record 44 of Set 4 | chapais
# Processing Record 45 of Set 4 | korla
# Processing Record 46 of Set 4 | keflavik
# Processing Record 47 of Set 4 | aden
# Processing Record 48 of Set 4 | kutum
# Processing Record 49 of Set 4 | thinadhoo
# Processing Record 50 of Set 4 | morristown
# Processing Record 1 of Set 5 | kolondieba
# Processing Record 2 of Set 5 | constantine
# Processing Record 3 of Set 5 | cajabamba
# Processing Record 4 of Set 5 | kataysk
# Processing Record 5 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 6 of Set 5 | itarema
# Processing Record 7 of Set 5 | skibbereen
# Processing Record 8 of Set 5 | mufulira
# Processing Record 9 of Set 5 | lubumbashi
# Processing Record 10 of Set 5 | ayios matthaios
# City not found. Skipping...
# Processing Record 11 of Set 5 | mangan
# Processing Record 12 of Set 5 | saint-augustin
# Processing Record 13 of Set 5 | mehamn
# Processing Record 14 of Set 5 | manoel urbano
# Processing Record 15 of Set 5 | arvika
# Processing Record 16 of Set 5 | grindavik
# Processing Record 17 of Set 5 | sayyan
# Processing Record 18 of Set 5 | mogadishu
# Processing Record 19 of Set 5 | metsavan
# Processing Record 20 of Set 5 | geneva
# Processing Record 21 of Set 5 | vardo
# Processing Record 22 of Set 5 | falun
# Processing Record 23 of Set 5 | omboue
# Processing Record 24 of Set 5 | varzea da palma
# Processing Record 25 of Set 5 | xapuri
# Processing Record 26 of Set 5 | samfya
# Processing Record 27 of Set 5 | bridlington
# Processing Record 28 of Set 5 | salto
# Processing Record 29 of Set 5 | nouakchott
# Processing Record 30 of Set 5 | abu samrah
# Processing Record 31 of Set 5 | schaffhausen
# Processing Record 32 of Set 5 | qaqortoq
# Processing Record 33 of Set 5 | nivala
# Processing Record 34 of Set 5 | minudasht
# Processing Record 35 of Set 5 | haputale
# Processing Record 36 of Set 5 | itaueira
# Processing Record 37 of Set 5 | sal rei
# Processing Record 38 of Set 5 | moose factory
# Processing Record 39 of Set 5 | chimbote
# Processing Record 40 of Set 5 | beloha
# Processing Record 41 of Set 5 | jaisalmer
# Processing Record 42 of Set 5 | ginir
# Processing Record 43 of Set 5 | aquiraz
# Processing Record 44 of Set 5 | oranjemund
# Processing Record 45 of Set 5 | klaksvik
# Processing Record 46 of Set 5 | kologriv
# Processing Record 47 of Set 5 | kaabong
# Processing Record 48 of Set 5 | shihezi
# Processing Record 49 of Set 5 | caravelas
# Processing Record 50 of Set 5 | walvis bay
# Processing Record 1 of Set 6 | sisimiut
# Processing Record 2 of Set 6 | punta arenas
# Processing Record 3 of Set 6 | maun
# Processing Record 4 of Set 6 | husavik
# Processing Record 5 of Set 6 | terekli-mekteb
# Processing Record 6 of Set 6 | ilulissat
# Processing Record 7 of Set 6 | santa maria
# Processing Record 8 of Set 6 | laguna
# Processing Record 9 of Set 6 | fonte boa
# Processing Record 10 of Set 6 | viedma
# Processing Record 11 of Set 6 | maltahohe
# Processing Record 12 of Set 6 | marawi
# Processing Record 13 of Set 6 | rincon
# Processing Record 14 of Set 6 | sovetsk
# Processing Record 15 of Set 6 | rio grande
# Processing Record 16 of Set 6 | bokoro
# Processing Record 17 of Set 6 | maldonado
# Processing Record 18 of Set 6 | sechura
# Processing Record 19 of Set 6 | douala
# Processing Record 20 of Set 6 | bayonet point
# Processing Record 21 of Set 6 | florianopolis
# Processing Record 22 of Set 6 | zonguldak
# Processing Record 23 of Set 6 | kalmunai
# Processing Record 24 of Set 6 | buritizeiro
# Processing Record 25 of Set 6 | kautokeino
# Processing Record 26 of Set 6 | binghamton
# Processing Record 27 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 6 | timmins
# Processing Record 29 of Set 6 | maceio
# Processing Record 30 of Set 6 | tisul
# Processing Record 31 of Set 6 | sayat
# Processing Record 32 of Set 6 | puerto cabezas
# Processing Record 33 of Set 6 | antalaha
# Processing Record 34 of Set 6 | port blair
# Processing Record 35 of Set 6 | leh
# Processing Record 36 of Set 6 | canakkale
# Processing Record 37 of Set 6 | illapel
# Processing Record 38 of Set 6 | umm lajj
# Processing Record 39 of Set 6 | mbaiki
# Processing Record 40 of Set 6 | tarko-sale
# Processing Record 41 of Set 6 | buta
# Processing Record 42 of Set 6 | iberia
# Processing Record 43 of Set 6 | shieli
# Processing Record 44 of Set 6 | timra
# Processing Record 45 of Set 6 | yagoua
# Processing Record 46 of Set 6 | aranda de duero
# Processing Record 47 of Set 6 | malakal
# Processing Record 48 of Set 6 | port saint john
# Processing Record 49 of Set 6 | quthing
# Processing Record 50 of Set 6 | oxford
# Processing Record 1 of Set 7 | north vernon
# Processing Record 2 of Set 7 | ajaccio
# Processing Record 3 of Set 7 | teya
# Processing Record 4 of Set 7 | kolyvan
# Processing Record 5 of Set 7 | chongoyape
# Processing Record 6 of Set 7 | la palma
# Processing Record 7 of Set 7 | grimari
# City not found. Skipping...
# Processing Record 8 of Set 7 | tazovskiy
# Processing Record 9 of Set 7 | llanelli
# Processing Record 10 of Set 7 | porto novo
# Processing Record 11 of Set 7 | aras
# Processing Record 12 of Set 7 | abu dhabi
# Processing Record 13 of Set 7 | plakhtiyivka
# Processing Record 14 of Set 7 | dire
# Processing Record 15 of Set 7 | nakasongola
# Processing Record 16 of Set 7 | taltal
# Processing Record 17 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 18 of Set 7 | lima
# Processing Record 19 of Set 7 | dalvik
# Processing Record 20 of Set 7 | kabo
# Processing Record 21 of Set 7 | aubenas
# Processing Record 22 of Set 7 | temirgoyevskaya
# Processing Record 23 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 24 of Set 7 | acari
# Processing Record 25 of Set 7 | kayes
# Processing Record 26 of Set 7 | mayumba
# Processing Record 27 of Set 7 | nyzy
# Processing Record 28 of Set 7 | jalu
# Processing Record 29 of Set 7 | johnstown
# Processing Record 30 of Set 7 | black river
# Processing Record 31 of Set 7 | lethem
# Processing Record 32 of Set 7 | masakin
# Processing Record 33 of Set 7 | caceres
# Processing Record 34 of Set 7 | shrigonda
# Processing Record 35 of Set 7 | iqaluit
# Processing Record 36 of Set 7 | mbandaka
# Processing Record 37 of Set 7 | westport
# Processing Record 38 of Set 7 | anar darreh
# City not found. Skipping...
# Processing Record 39 of Set 7 | parabel
# Processing Record 40 of Set 7 | saint-pierre
# Processing Record 41 of Set 7 | barbosa ferraz
# Processing Record 42 of Set 7 | castro
# Processing Record 43 of Set 7 | mizan teferi
# Processing Record 44 of Set 7 | yar-sale
# Processing Record 45 of Set 7 | kokomo
# Processing Record 46 of Set 7 | tazmalt
# Processing Record 47 of Set 7 | minas
# Processing Record 48 of Set 7 | qunduz
# Processing Record 49 of Set 7 | lyngseidet
# Processing Record 50 of Set 7 | tupancireta
# Processing Record 1 of Set 8 | corn island
# Processing Record 2 of Set 8 | campoverde
# Processing Record 3 of Set 8 | chingirlau
# Processing Record 4 of Set 8 | kozhevnikovo
# Processing Record 5 of Set 8 | nanortalik
# Processing Record 6 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 7 of Set 8 | old orchard beach
# Processing Record 8 of Set 8 | mozarlandia
# Processing Record 9 of Set 8 | visby
# Processing Record 10 of Set 8 | micheweni
# Processing Record 11 of Set 8 | bimbo
# Processing Record 12 of Set 8 | tabou
# Processing Record 13 of Set 8 | beachwood
# Processing Record 14 of Set 8 | stornoway
# Processing Record 15 of Set 8 | bay roberts
# Processing Record 16 of Set 8 | mahebourg
# Processing Record 17 of Set 8 | hearst
# Processing Record 18 of Set 8 | plettenberg bay
# Processing Record 19 of Set 8 | cayenne
# Processing Record 20 of Set 8 | zabolottya
# City not found. Skipping...
# Processing Record 21 of Set 8 | paamiut
# Processing Record 22 of Set 8 | bengkulu
# Processing Record 23 of Set 8 | pocinhos
# Processing Record 24 of Set 8 | zavodouspenskoye
# Processing Record 25 of Set 8 | paso de patria
# Processing Record 26 of Set 8 | telemaco borba
# Processing Record 27 of Set 8 | don benito
# Processing Record 28 of Set 8 | port hawkesbury
# Processing Record 29 of Set 8 | veraval
# Processing Record 30 of Set 8 | zlitan
# Processing Record 31 of Set 8 | shakiso
# Processing Record 32 of Set 8 | stamsund
# City not found. Skipping...
# Processing Record 33 of Set 8 | prainha
# Processing Record 34 of Set 8 | owensboro
# Processing Record 35 of Set 8 | pozo colorado
# Processing Record 36 of Set 8 | bani walid
# Processing Record 37 of Set 8 | mabamba
# Processing Record 38 of Set 8 | ilo
# Processing Record 39 of Set 8 | antigonish
# Processing Record 40 of Set 8 | puerto escondido
# Processing Record 41 of Set 8 | mehkar
# Processing Record 42 of Set 8 | kortkeros
# Processing Record 43 of Set 8 | birao
# Processing Record 44 of Set 8 | gonaives
# Processing Record 45 of Set 8 | itaobim
# Processing Record 46 of Set 8 | bonthe
# Processing Record 47 of Set 8 | havre-saint-pierre
# Processing Record 48 of Set 8 | opuwo
# Processing Record 49 of Set 8 | tveit
# Processing Record 50 of Set 8 | matara
# Processing Record 1 of Set 9 | lagoa formosa
# Processing Record 2 of Set 9 | abancay
# Processing Record 3 of Set 9 | bahia honda
# Processing Record 4 of Set 9 | muisne
# Processing Record 5 of Set 9 | kaura namoda
# Processing Record 6 of Set 9 | blyth
# Processing Record 7 of Set 9 | nizhniy chir
# Processing Record 8 of Set 9 | kattivakkam
# Processing Record 9 of Set 9 | wilmington island
# Processing Record 10 of Set 9 | luanda
# Processing Record 11 of Set 9 | pitimbu
# Processing Record 12 of Set 9 | khorixas
# Processing Record 13 of Set 9 | paragominas
# Processing Record 14 of Set 9 | do rud
# City not found. Skipping...
# Processing Record 15 of Set 9 | jacqueville
# Processing Record 16 of Set 9 | temirtau
# Processing Record 17 of Set 9 | moravska trebova
# Processing Record 18 of Set 9 | mana
# Processing Record 19 of Set 9 | ambilobe
# Processing Record 20 of Set 9 | boden
# Processing Record 21 of Set 9 | alta floresta
# Processing Record 22 of Set 9 | yevlax
# Processing Record 23 of Set 9 | lagoa
# Processing Record 24 of Set 9 | la rioja
# Processing Record 25 of Set 9 | laje
# Processing Record 26 of Set 9 | dingle
# Processing Record 27 of Set 9 | ihosy
# Processing Record 28 of Set 9 | kangaatsiaq
# Processing Record 29 of Set 9 | schwarzenbek
# Processing Record 30 of Set 9 | salamanca
# Processing Record 31 of Set 9 | berzovia
# Processing Record 32 of Set 9 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 33 of Set 9 | pisco
# Processing Record 34 of Set 9 | sovetskiy
# Processing Record 35 of Set 9 | ferme-neuve
# Processing Record 36 of Set 9 | gat
# Processing Record 37 of Set 9 | butterworth
# Processing Record 38 of Set 9 | usinsk
# Processing Record 39 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 40 of Set 9 | nizhniy odes
# Processing Record 41 of Set 9 | manati
# Processing Record 42 of Set 9 | faya
# Processing Record 43 of Set 9 | mahajanga
# Processing Record 44 of Set 9 | paita
# Processing Record 45 of Set 9 | pedernales
# Processing Record 46 of Set 9 | birur
# Processing Record 47 of Set 9 | ginda
# Processing Record 48 of Set 9 | brunico
# Processing Record 49 of Set 9 | cabo rojo
# Processing Record 50 of Set 9 | abu zabad
# Processing Record 1 of Set 10 | bathsheba
# Processing Record 2 of Set 10 | vredendal
# Processing Record 3 of Set 10 | bara
# Processing Record 4 of Set 10 | andijon
# Processing Record 5 of Set 10 | pocone
# Processing Record 6 of Set 10 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 7 of Set 10 | murdochville
# Processing Record 8 of Set 10 | asilah
# Processing Record 9 of Set 10 | kasongo-lunda
# Processing Record 10 of Set 10 | danville
# Processing Record 11 of Set 10 | tornio
# Processing Record 12 of Set 10 | kaliua
# Processing Record 13 of Set 10 | liverpool
# Processing Record 14 of Set 10 | padang
# Processing Record 15 of Set 10 | tromso
# Processing Record 16 of Set 10 | sumbe
# Processing Record 17 of Set 10 | ribas do rio pardo
# Processing Record 18 of Set 10 | henties bay
# Processing Record 19 of Set 10 | dutse
# Processing Record 20 of Set 10 | mizdah
# Processing Record 21 of Set 10 | burica
# City not found. Skipping...
# Processing Record 22 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 23 of Set 10 | sesheke
# Processing Record 24 of Set 10 | rawson
# Processing Record 25 of Set 10 | severodvinsk
# Processing Record 26 of Set 10 | agadir
# Processing Record 27 of Set 10 | pangnirtung
# Processing Record 28 of Set 10 | salinopolis
# Processing Record 29 of Set 10 | san roque
# Processing Record 30 of Set 10 | los llanos de aridane
# Processing Record 31 of Set 10 | matay
# Processing Record 32 of Set 10 | villablino
# Processing Record 33 of Set 10 | oistins
# Processing Record 34 of Set 10 | bar harbor
# Processing Record 35 of Set 10 | usogorsk
# Processing Record 36 of Set 10 | kashi
# Processing Record 37 of Set 10 | rio gallegos
# Processing Record 38 of Set 10 | pangody
# Processing Record 39 of Set 10 | neustadt
# Processing Record 40 of Set 10 | sao felix do xingu
# Processing Record 41 of Set 10 | cap malheureux
# Processing Record 42 of Set 10 | matagami
# Processing Record 43 of Set 10 | new castle
# Processing Record 44 of Set 10 | sao gabriel da cachoeira
# Processing Record 45 of Set 10 | aswan
# Processing Record 46 of Set 10 | praia da vitoria
# Processing Record 47 of Set 10 | kemijarvi
# Processing Record 48 of Set 10 | muzhi
# Processing Record 49 of Set 10 | port-gentil
# Processing Record 50 of Set 10 | wilmington
# Processing Record 1 of Set 11 | tres lagoas
# Processing Record 2 of Set 11 | northview
# Processing Record 3 of Set 11 | cockburn town
# Processing Record 4 of Set 11 | stilfontein
# Processing Record 5 of Set 11 | albany
# Processing Record 6 of Set 11 | aksarka
# Processing Record 7 of Set 11 | karlshamn
# Processing Record 8 of Set 11 | grand-santi
# Processing Record 9 of Set 11 | hurghada
# Processing Record 10 of Set 11 | ouesso
# Processing Record 11 of Set 11 | sao jose do belmonte
# Processing Record 12 of Set 11 | madinat sittah uktubar
# Processing Record 13 of Set 11 | onguday
# Processing Record 14 of Set 11 | dovbysh
# Processing Record 15 of Set 11 | warrington
# Processing Record 16 of Set 11 | soyo
# Processing Record 17 of Set 11 | riaba
# City not found. Skipping...
# Processing Record 18 of Set 11 | nioro
# Processing Record 19 of Set 11 | najran
# Processing Record 20 of Set 11 | tuntum
# Processing Record 21 of Set 11 | cravo norte
# Processing Record 22 of Set 11 | haradok
# Processing Record 23 of Set 11 | batouri
# Processing Record 24 of Set 11 | sept-iles
# Processing Record 25 of Set 11 | tres arroyos
# Processing Record 26 of Set 11 | fort-shevchenko
# Processing Record 27 of Set 11 | contamana
# Processing Record 28 of Set 11 | teguldet
# Processing Record 29 of Set 11 | bushehr
# Processing Record 30 of Set 11 | coihaique
# Processing Record 31 of Set 11 | honningsvag
# Processing Record 32 of Set 11 | cumra
# Processing Record 33 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 34 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 35 of Set 11 | ondangwa
# Processing Record 36 of Set 11 | sao mateus
# Processing Record 37 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 39 of Set 11 | semnan
# Processing Record 40 of Set 11 | lasa
# Processing Record 41 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 42 of Set 11 | kudahuvadhoo
# Processing Record 43 of Set 11 | gasa
# Processing Record 44 of Set 11 | sabha
# Processing Record 45 of Set 11 | dasoguz
# Processing Record 46 of Set 11 | homa bay
# Processing Record 47 of Set 11 | rybachiy
# Processing Record 48 of Set 11 | cusuna
# Processing Record 49 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 11 | los andes
# Processing Record 1 of Set 12 | mangrul pir
# Processing Record 2 of Set 12 | ambanja
# Processing Record 3 of Set 12 | marystown
# Processing Record 4 of Set 12 | nortelandia
# Processing Record 5 of Set 12 | abha
# Processing Record 6 of Set 12 | brae
# Processing Record 7 of Set 12 | benghazi
# Processing Record 8 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 9 of Set 12 | vazante
# Processing Record 10 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 12 | colares
# Processing Record 12 of Set 12 | mingoyo
# Processing Record 13 of Set 12 | muravlenko
# Processing Record 14 of Set 12 | synya
# Processing Record 15 of Set 12 | ati
# Processing Record 16 of Set 12 | uribia
# Processing Record 17 of Set 12 | santa teresa
# Processing Record 18 of Set 12 | guaratinga
# Processing Record 19 of Set 12 | porto velho
# Processing Record 20 of Set 12 | belyy yar
# Processing Record 21 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 22 of Set 12 | mossendjo
# Processing Record 23 of Set 12 | windhoek
# Processing Record 24 of Set 12 | viransehir
# Processing Record 25 of Set 12 | urshelskiy
# Processing Record 26 of Set 12 | coari
# Processing Record 27 of Set 12 | bremervorde
# Processing Record 28 of Set 12 | kenscoff
# Processing Record 29 of Set 12 | afsin
# Processing Record 30 of Set 12 | naron
# Processing Record 31 of Set 12 | saint-leu
# Processing Record 32 of Set 12 | harbour breton
# Processing Record 33 of Set 12 | ancud
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
city_data_df = city_data_df[['City','Country', 'Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-adbaf1a23830> in <module>
#       1 # Convert the array of dictionaries to a Pandas DataFrame.
# ----> 2 city_data_df = pd.DataFrame(city_data)
#       3 city_data_df.head(10)
#       4 city_data_df = city_data_df[['City','Country', 'Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed']]
#
# NameError: name 'pd' is not defined

# %%
# Create the output file (CSV).
output_data_file = "Data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7a42c5b26c6f> in <module>
#       2 output_data_file = "Data/cities.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# NameError: name 'city_data_df' is not defined

# %%
city_data_df=pd.read_csv("Data/cities.csv")

# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("Data/Fig1.png")

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("Data/Fig2.png")

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("Data/Fig3.png")

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("Data/Fig4.png")

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.  
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Northern Hemisphere \n for Maximum Temperature', 'Max Temp',(10,20))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere \n for Maximum Temperature', 'Max Temp',(-50,75))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Northern Hemisphere \n for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere \n for % Humidity', '% Humidity',(-50,30))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Northern Hemisphere \n for % Cloudiness', '% Cloudiness',(15,65))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(-55,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Northern Hemisphere \nfor Wind Speed', 'Wind Speed',(0,25))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere \nfor Wind Speed', 'Wind Speed',(-30,17.5))
